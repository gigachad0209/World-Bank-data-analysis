# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127667_americas_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0           93763.0            48981.0          44782.0   18.184992
# 1           93219.0            48708.0          44511.0   12.115000
# 2           92664.0            48428.0          44236.0   12.160000
# 3           92117.0            48156.0          43961.0   11.485000
# 4           91626.0            47911.0          43715.0   10.816000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    6.828165                       11.0                  20.153997
# 1    6.365000                       11.0                  20.153997
# 2    5.961000                       11.0                  20.153997
# 3    5.865000                       11.0                  20.153997
# 4    5.787000                       11.0                  20.153997
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     17.004881                             8.655858
# 1                     17.004881                             8.655858
# 2                     17.004881                             8.655858
# 3                     17.004881                             8.655858
# 4                     17.004881                             8.655858
#
#    Female Employment in Industry(%)  ...  Renewable Energy Consumption (%)  \
# 0                          11.81121  ...                         21.149982
# 1                          11.81121  ...                          0.720000
# 2                          11.81121  ...                          0.740000
# 3                          11.81121  ...                          0.690000
# 4                          11.81121  ...                          0.700000
#
#    Fossil Fuel Consumption (%)  Male life expectancy  Female life expectancy   \
# 0                    63.452255              70.19852                 76.07276
# 1                    63.452255              75.77500                 80.94100
# 2                    63.452255              76.06100                 81.31600
# 3                    63.452255              75.90900                 81.17100
# 4                    63.452255              75.72400                 81.00000
#
#    School enrollment, primary  School enrollment, tertiary  \
# 0                  106.128710                    39.528947
# 1                  106.128710                    39.528947
# 2                  106.128710                    39.528947
# 3                  112.122238                    39.528947
# 4                  112.091682                    39.528947
#
#    Primary completion rate  Literacy rate  Year              Country
# 0                95.522408      97.105964  2022  Antigua and Barbuda
# 1                95.522408      97.105964  2021  Antigua and Barbuda
# 2                95.522408      97.105964  2020  Antigua and Barbuda
# 3               104.976669      97.105964  2019  Antigua and Barbuda
# 4               104.444443      97.105964  2018  Antigua and Barbuda
#
# [5 rows x 26 columns]

# %%
# TEST
cleaned_df.shape
# Out:
# (1204, 26)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.204000e+03       1.204000e+03     1.204000e+03  1204.000000
# mean       2.126095e+07       1.075849e+07     1.050246e+07    18.184992
# std        5.505953e+07       2.791240e+07     2.714762e+07     5.728701
# min        1.510100e+04       7.336000e+03     7.765000e+03     5.900000
# 25%        1.091660e+05       5.645700e+04     5.554250e+04    13.767000
# 50%        3.422497e+06       1.764235e+06     1.658096e+06    17.602500
# 75%        1.194908e+07       5.975354e+06     5.995499e+06    22.027250
# max        3.332876e+08       1.682662e+08     1.650213e+08    37.349000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1204.000000                1204.000000                1204.000000
# mean      6.828165                  10.879921                  20.153997
# std       1.721987                   2.510386                   3.128110
# min       2.800000                   6.000000                  10.386770
# 25%       5.590250                   9.000000                  18.713608
# 50%       6.828165                  11.000000                  20.153997
# 75%       7.836750                  12.000000                  21.871533
# max      17.738000                  17.000000                  32.266680
#
#        Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# count                   1204.000000                          1204.000000
# mean                      17.004881                             8.655858
# std                       10.185105                             7.958425
# min                        1.128129                             0.094002
# 25%                       10.670777                             3.891058
# 50%                       17.004881                             8.310724
# 75%                       19.691680                             8.655858
# max                       52.982150                            42.189880
#
#        Female Employment in Industry(%)  ...  Agriculture value added(in USD)  \
# count                       1204.000000  ...                     1.204000e+03
# mean                          11.811210  ...                     9.465944e+09
# std                            3.870891  ...                     2.610442e+10
# min                            3.099745  ...                     3.486034e+05
# 25%                            9.503683  ...                     1.035674e+08
# 50%                           11.811210  ...                     1.505479e+09
# 75%                           12.415630  ...                     9.465944e+09
# max                           27.820870  ...                     2.237237e+11
#
#        Electric Power Consumption(kWH per capita)  \
# count                                 1204.000000
# mean                                  2620.246216
# std                                   2439.693577
# min                                     23.915832
# 25%                                   1868.859189
# 50%                                   2620.246216
# 75%                                   2620.246216
# max                                  17264.736744
#
#        Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  \
# count                       1204.000000                  1204.000000
# mean                          21.149982                    63.452255
# std                           19.897091                    17.863313
# min                            0.000000                     0.000000
# 25%                            5.245000                    63.452255
# 50%                           16.665000                    63.452255
# 75%                           31.440000                    69.753488
# max                           86.990000                    99.929949
#
#        Male life expectancy  Female life expectancy   \
# count           1204.000000              1204.000000
# mean              70.198520                76.072760
# std                4.207327                 4.345992
# min               45.758000                46.251000
# 25%               68.190750                74.094250
# 50%               70.198520                76.225000
# 75%               72.992500                78.855500
# max               80.621000                85.855000
#
#        School enrollment, primary  School enrollment, tertiary  \
# count                 1204.000000                  1204.000000
# mean                   106.128710                    39.528947
# std                      7.355744                    16.324976
# min                     72.597130                     0.117370
# 25%                    102.377203                    37.783577
# 50%                    106.128710                    39.528947
# 75%                    109.840109                    39.528947
# max                    148.712952                   117.719940
#
#        Primary completion rate  Literacy rate
# count              1204.000000    1204.000000
# mean                 95.522408      97.105964
# std                   8.274955       1.669140
# min                  46.638149      72.346718
# 25%                  95.522408      97.105964
# 50%                  95.522408      97.105964
# 75%                  97.884462      97.105964
# max                 152.806656     100.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# **TODO**: Give your obervation here
#
# ...
#
# ...

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
df_Q1 = cleaned_df.copy()
df_Q1.drop(['Year', 'Country'], inplace=True, axis='columns')
df_Q1.sort_values(by=['Total Population'])
new_df = df_Q1.head(10)
new_df
# YOUR CODE HERE (OPTION)
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0           93763.0            48981.0          44782.0   18.184992
# 1           93219.0            48708.0          44511.0   12.115000
# 2           92664.0            48428.0          44236.0   12.160000
# 3           92117.0            48156.0          43961.0   11.485000
# 4           91626.0            47911.0          43715.0   10.816000
# 5           91119.0            47658.0          43461.0   11.789000
# 6           90564.0            47388.0          43176.0   11.659000
# 7           89941.0            47088.0          42853.0   12.591000
# 8           89236.0            46748.0          42488.0   12.325000
# 9           88497.0            46401.0          42096.0   12.469000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    6.828165                       11.0                  20.153997
# 1    6.365000                       11.0                  20.153997
# 2    5.961000                       11.0                  20.153997
# 3    5.865000                       11.0                  20.153997
# 4    5.787000                       11.0                  20.153997
# 5    5.746000                       11.0                  20.153997
# 6    5.662000                       11.0                  20.153997
# 7    5.649000                       11.0                  20.153997
# 8    5.544000                       11.0                  20.153997
# 9    5.565000                       11.0                  20.153997
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     17.004881                             8.655858
# 1                     17.004881                             8.655858
# 2                     17.004881                             8.655858
# 3                     17.004881                             8.655858
# 4                     17.004881                             8.655858
# 5                     17.004881                             8.655858
# 6                     17.004881                             8.655858
# 7                     17.004881                             8.655858
# 8                     17.004881                             8.655858
# 9                     17.004881                             8.655858
#
#    Female Employment in Industry(%)  ...  Agriculture value added(in USD)  \
# 0                          11.81121  ...                     3.264444e+07
# 1                          11.81121  ...                     3.097037e+07
# 2                          11.81121  ...                     3.034074e+07
# 3                          11.81121  ...                     2.925185e+07
# 4                          11.81121  ...                     2.787778e+07
# 5                          11.81121  ...                     2.630741e+07
# 6                          11.81121  ...                     2.252593e+07
# 7                          11.81121  ...                     2.155185e+07
# 8                          11.81121  ...                     2.069259e+07
# 9                          11.81121  ...                     2.383333e+07
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                 2620.246216
# 1                                 2620.246216
# 2                                 2620.246216
# 3                                 2620.246216
# 4                                 2620.246216
# 5                                 2620.246216
# 6                                 2620.246216
# 7                                 2620.246216
# 8                                 2620.246216
# 9                                 2620.246216
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  \
# 0                         21.149982                    63.452255
# 1                          0.720000                    63.452255
# 2                          0.740000                    63.452255
# 3                          0.690000                    63.452255
# 4                          0.700000                    63.452255
# 5                          0.450000                    63.452255
# 6                          0.450000                    63.452255
# 7                          0.360000                    63.452255
# 8                          0.110000                    63.452255
# 9                          0.110000                    63.452255
#
#    Male life expectancy  Female life expectancy   School enrollment, primary  \
# 0              70.19852                 76.07276                  106.128710
# 1              75.77500                 80.94100                  106.128710
# 2              76.06100                 81.31600                  106.128710
# 3              75.90900                 81.17100                  112.122238
# 4              75.72400                 81.00000                  112.091682
# 5              75.52000                 80.72100                  109.164749
# 6              75.36600                 80.64500                  106.868645
# 7              75.14800                 80.38900                  109.831062
# 8              74.90800                 80.53500                  111.841667
# 9              74.67100                 80.23000                  112.632629
#
#    School enrollment, tertiary  Primary completion rate  Literacy rate
# 0                    39.528947                95.522408      97.105964
# 1                    39.528947                95.522408      97.105964
# 2                    39.528947                95.522408      97.105964
# 3                    39.528947               104.976669      97.105964
# 4                    39.528947               104.444443      97.105964
# 5                    39.528947               107.808762      97.105964
# 6                    39.528947               102.687744      97.105964
# 7                    39.528947               100.388199      97.105964
# 8                    39.528947               119.137672      97.105964
# 9                    39.528947               114.097885      97.105964
#
# [10 rows x 24 columns]

# %%
# YOUR CODE HERE
df_Q1 = cleaned_df.copy()
df_Q1.drop(['Year', 'Country'], inplace=True, axis='columns')
df_Q1.sort_values(by=['Total Population'])
new_df = df_Q1.head(10)

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(new_df.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
df_Q2 = cleaned_df.copy()
df_Q2.drop(['Year', 'Country'], inplace=True, axis='columns')
df_Q2.sort_values(by=['Total Population'], ascending=False)
new_df_2 = df_Q2.head(10)

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(new_df_2.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# Example: Is that possible to drop any features that have less effect?

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate    Country
# 22       28.940357  Guatemala
# 24       27.961714      Haiti
# 25       27.421750   Honduras
# 7        26.289464    Bolivia
# 5        24.881107     Belize

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df .index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate              Country
# 16       10.081113             Dominica
# 24        9.555292                Haiti
# 40        9.377899              Uruguay
# 33        9.339327  St. Kitts and Nevis
# 4         9.075256             Barbados

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here
#
# ...
#
# ...

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **Question 1:** What is the unemployment situation of the countries in the continent?

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
unemploy_df = pd.DataFrame()

unemploy_df["Average unemployment(%)"] = cleaned_df.groupby("Country")["Unemployment(%)"].mean()

unemploy_df["Country"] = unemploy_df.index

unemploy_df.reset_index(drop=True, inplace=True)

unemploy_df.sort_values("Average unemployment(%)", inplace=True, ascending=False)

unemploy_df.head()
# Out:
#     Average unemployment(%)                         Country
# 35                19.669607  St. Vincent and the Grenadines
# 34                18.462357                       St. Lucia
# 24                12.691214                           Haiti
# 23                12.351893                          Guyana
# 13                11.957107                        Colombia

# %%
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=unemploy_df.head(), x="Country", y= "Average unemployment(%)")

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **Question 2:** What is the male and female population in the countries on the continent?

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE

male_female_df = pd.DataFrame()
male_female_df["Average male population"] = cleaned_df.groupby("Country")["Male Population"].mean()
male_female_df["Average female population"] = cleaned_df.groupby("Country")["Female Population"].mean()
male_female_df["Average population"] = cleaned_df.groupby("Country")["Total Population"].mean()

male_female_df["Country"] = male_female_df.index

male_female_df.reset_index(drop=True, inplace=True)

male_female_df.sort_values("Average population", inplace=True, ascending=False)

male_female_df.head()
# Out:
#     Average male population  Average female population  Average population  \
# 39             1.497015e+08               1.537646e+08        3.034662e+08
# 8              9.485952e+07               9.739628e+07        1.922558e+08
# 27             5.390852e+07               5.623676e+07        1.101453e+08
# 13             2.175693e+07               2.219925e+07        4.395618e+07
# 1              2.000977e+07               2.049304e+07        4.050282e+07
#
#           Country
# 39  United States
# 8          Brazil
# 27         Mexico
# 13       Colombia
# 1       Argentina

# %%
X_axis = np.arange(5)
plt.bar(X_axis - 0.2, male_female_df.head(5)["Average female population"], 0.4, label = 'Female') 
plt.bar(X_axis + 0.2, male_female_df.head(5)["Average male population"], 0.4, label = 'Male') 


plt.xticks(X_axis, male_female_df.head(5)["Country"]) 
plt.xlabel("Country") 
plt.ylabel("Population count") 
plt.title("Male and female comparison") 
plt.legend() 
plt.show()

# %% [markdown]
# ## Question 3: What are the emplyment rate on agriculture and industry in countries with highest GDP?

# %%
Q3_df = pd.DataFrame()
Q3_df["Average agriculture employment"] = cleaned_df.groupby("Country")["Employment in Agriculture(%)"].mean()
Q3_df["Average industry employment"] = cleaned_df.groupby("Country")["Employment in Industry(%)"].mean()
Q3_df["Average GDP in USD"] = cleaned_df.groupby("Country")["GDP in USD"].mean()

Q3_df["Country"] = Q3_df.index

Q3_df.reset_index(drop=True, inplace=True)

Q3_df.sort_values("Average GDP in USD", inplace=True, ascending=False)

Q3_df.head()
# Out:
#     Average agriculture employment  Average industry employment  \
# 39                        2.457154                    21.029042
# 8                        13.578017                    22.247026
# 10                        2.605808                    21.308423
# 27                       15.662716                    24.893072
# 9                        17.004881                    20.153997
#
#     Average GDP in USD                 Country
# 39        1.494372e+13           United States
# 8         1.442673e+12                  Brazil
# 10        1.326516e+12                  Canada
# 27        9.560535e+11                  Mexico
# 9         5.000622e+11  British Virgin Islands

# %%
X_axis = np.arange(5)
plt.bar(X_axis - 0.2, Q3_df.head(5)["Average agriculture employment"], 0.4, label = 'Agriculture') 
plt.bar(X_axis + 0.2, Q3_df.head(5)["Average industry employment"], 0.4, label = 'Industry') 


plt.xticks(X_axis, male_female_df.head(5)["Country"]) 
plt.xlabel("Country") 
plt.ylabel("Population count") 
plt.title("Industry and Agriculture") 
plt.legend() 
plt.show()

# %% [markdown]
# ## Question 4: Does a country have a high GDP also have national income per capita?

# %%
Q4_df = pd.DataFrame()
Q4_df["Average GDP"] = cleaned_df.groupby("Country")["GDP in USD"].mean()

Q4_df["Country"] = Q4_df.index

Q4_df.reset_index(drop=True, inplace=True)

Q4_df.sort_values("Average GDP", inplace=True, ascending=False)


plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=Q4_df.head(), x="Country", y= "Average GDP")

# %%
Q4_2_df = pd.DataFrame()
Q4_2_df["Average National Income per Capita"] = cleaned_df.groupby("Country")["National Income per Capita"].mean()

Q4_2_df["Country"] = Q4_2_df.index

Q4_2_df.reset_index(drop=True, inplace=True)

# Q4_2_df.sort_values("Average National Income per Capita", inplace=True, ascending=False)
us_value = Q4_2_df.loc[Q4_2_df['Country'] == 'United States']["Average National Income per Capita"]
brazil_value = Q4_2_df.loc[Q4_2_df['Country'] == 'Brazil']["Average National Income per Capita"]
mex_value = Q4_2_df.loc[Q4_2_df['Country'] == 'Mexico']["Average National Income per Capita"]
bri_value = Q4_2_df.loc[Q4_2_df['Country'] == 'British Virgin Islands']["Average National Income per Capita"]


country = ['United States', 'Brazil', 'Mexico', 'British Virgin Islands']
income_val = [us_value, brazil_value, mex_value, bri_value]

y_value = []
for x in income_val:
    x = str(x)
    x = x[5:9]
    y_value.append(float(x))

fig = plt.figure(figsize = (10, 5))

plt.bar(country, y_value, color ='maroon', 
        width = 0.4) 
plt.xlabel("Countries")
plt.ylabel("Average National Income per Capita")
plt.show()
# Out:
# 1.4
# 1.12
# 0.2
# 1.52
